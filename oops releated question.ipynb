# %%
class BankAccount:()
 
def __init__(self,account_holder):
        self.account_holder=account_holder
        self.balance=0

def deposit(self,amount):
        self.balance += amount
        if amount > 0:
            print("deposited: ", amount)
        else:
            print("invalid deposit amount")

def withdraw(self,amount):
        self.balance -= amount
        if amount <= self.balance:
            print("withdrawn: ",amount)
        else:
            print("insufficent balance")

def display_balance(self):
        print("Account holder: ", self.account_holder)
        print("current balance: ", self.balance)


account1.account_holder("zuba")

account1.deposit(1000)
account1.withdraw(300)
account1.withdraw(10000)
account1.display_balance()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[24], line 26
#      22         print("Account holder: ", self.account_holder)
#      23         print("current balance: ", self.balance)
# ---> 26 account1.account_holder("zuba")
#      28 account1.deposit(1000)
#      29 account1.withdraw(300)
#
# NameError: name 'account1' is not defined
